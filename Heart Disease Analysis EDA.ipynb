# %% [markdown]
# # Import The Libraries and Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("C:\\Users\\Avani\\Downloads\\archive\\heart.csv")

# %% [markdown]
# # Check first five rows of the dataset

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %% [markdown]
# # check last five rows of the dataset

# %%
data.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %% [markdown]
# # find shape of the dataset

# %%
data.shape
# Out:
# (1025, 14)

# %%
print("Number of Rows",data.shape[0])
print("Numer of Columns",data.shape[1])
# Out:
# Number of Rows 1025
# Numer of Columns 14

# %% [markdown]
# # information about datset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %% [markdown]
# # Check null values in the dataset

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
data_dup = data.duplicated().any()
print(data_dup)
# Out:
# True

# %%
data = data.drop_duplicates()

# %%
data.shape
# Out:
# (302, 14)

# %% [markdown]
# # Get overall statistics about the dataset

# %%
data.describe()
# Out:
#              age         sex          cp    trestbps        chol         fbs  \
# count  302.00000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053    0.682119    0.963576  131.602649  246.500000    0.149007
# std      9.04797    0.466426    1.032044   17.563394   51.753489    0.356686
# min     29.00000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.00000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.50000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.00000    1.000000    2.000000  140.000000  274.750000    0.000000
# max     77.00000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean     0.526490  149.569536    0.327815    1.043046    1.397351    0.718543
# ...

# %% [markdown]
# # Data Correlation matrix

# %%
plt.figure(figsize=(17,6))
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # How many people have heart disease, and how many don't have heart disease in the datset

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data['target'].value_counts() 
#value_count return the count of unique values
# Out:
# 1    164
# 0    138
# Name: target, dtype: int64

# %%
sns.countplot(data['target'])
plt.xticks([0,1],['Without Heart Disease','With Heart Disease'])
# Out:
# C:\Users\Avani\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ([<matplotlib.axis.XTick at 0x1d4a07f34c0>,
# ...
#  [Text(0, 0, 'Without Heart Disease'), Text(1, 0, 'With Heart Disease')])

# %% [markdown]
# # Find Count of female and males in the dataset

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data['sex'].value_counts()
# Out:
# 1    206
# 0     96
# Name: sex, dtype: int64

# %%
sns.countplot(data['sex'])
plt.xticks([0,1],['female','male'])
plt.show()
# Out:
# C:\Users\Avani\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Find Gender Distribution according to the Target Variable

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
sns.countplot(x='sex',hue="target",data=data)
plt.xticks([0,1],['female','male'])
plt.legend(labels=['No-Disease','Disease'])
plt.show()

# %% [markdown]
# # Check age distribution in dataset

# %%
sns.distplot(data['age'],bins=20)
plt.show()
# Out:
# C:\Users\Avani\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Chest pain type

# %%
sns.countplot(data['cp'])
plt.xticks([0,1,2,3],["typical angina","atypical angina","non-anginal pain","asymptomatic"])
plt.show()
# Out:
# C:\Users\Avani\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Chest pain distribution as per Target Variable

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
sns.countplot(x='cp',hue="target",data=data)
plt.legend(labels=["No-disease","Disease"])

plt.show()

# %% [markdown]
# # Show fasting blood sugar distribution according to target variable

# %%
sns.countplot(x='fbs',hue="target",data=data)
plt.legend(labels=["No-disease","Disease"])
plt.show()

# %% [markdown]
# # Check Resting Blood Pressure Distribution

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data['trestbps'].hist()
plt.show()

# %% [markdown]
# # Resting Blood Pressure As per Sex Column

# %%
g = sns.FacetGrid(data,hue="sex",aspect=4)
g.map(sns.kdeplot,'trestbps',shade=True)
plt.legend(labels=['male','female'])
plt.show()

# %% [markdown]
# # Distribution of serum cholesterol

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data['chol'].hist()
plt.show()

# %% [markdown]
# # Plotting Continuous Variables

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
Cate_val=[]
Cont_val=[]
for column in data.columns:
    if data[column].nunique() <=10:
        Cate_val.append(column)
    else:
        Cont_val.append(column)

# %%
Cate_val
# Out:
# ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal', 'target']

# %%
Cont_val
# Out:
# ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

# %%
data.hist(Cont_val,figsize=(15,6))
plt.tight_layout()
plt.show()
